# %%
import calml
import dummy

# %%
df = calml.get_hour_features('2014-01-01 00:00:00', '2018-03-15 00:00:00')

# %%
dummies = dummy.Dummies()
dummies.fit(df, ['year', 'season', 'month', 'monthday', 'weekday', 'hour'])
dm_df = dummies.replace(df)
dm_df.head()
# Out:
#                      holiday  year_2014  year_2015  year_2016  year_2017  \
# datetime
# 2014-01-01 00:00:00        1          1          0          0          0
# 2014-01-01 01:00:00        1          1          0          0          0
# 2014-01-01 02:00:00        1          1          0          0          0
# 2014-01-01 03:00:00        1          1          0          0          0
# 2014-01-01 04:00:00        1          1          0          0          0
#
#                      year_2018  season_1  season_2  season_3  season_4  \
# datetime
# 2014-01-01 00:00:00          0         1         0         0         0
# 2014-01-01 01:00:00          0         1         0         0         0
# 2014-01-01 02:00:00          0         1         0         0         0
# 2014-01-01 03:00:00          0         1         0         0         0
# 2014-01-01 04:00:00          0         1         0         0         0
#
#                        ...      hour_21  hour_22  hour_23  weekday_0  \
# ...

# %%
dm_df.to_csv('data/calendar.csv')
